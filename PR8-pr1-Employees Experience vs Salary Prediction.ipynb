# %% [markdown]
# # Project 1:
#
# # Predicting Salaries on basis of Experience in years through Linear Regression.
# ######
# | **Prepared by:** | Rayyan Ahmed.
# |------------------|--------------------------------------------------------------------------------|
# | **Date:**        | 28th May, 2024.                                                                |

# %% [markdown]
# ###
# ## Preparing DataFrame:
# ###

# %%
import pandas as pd

experience = [1.1, 1.3, 1.5, 2.0, 2.2, 2.9, 3.0, 3.2, 3.2, 3.7, 3.9, 4.0, 4.0, 4.1, 4.5, 4.9, 5.1, 5.3, 5.9, 6.0, 6.8, 7.1, 7.9, 8.2, 8.7, 9.0, 9.5, 9.6, 10.3, 10.5]
salary = [39343, 46205, 37731, 43525, 39891, 56642, 60150, 54445, 64445, 57189, 63218, 55794, 56957, 57081, 61111, 67938, 66029, 83088, 81363, 93940, 91738, 98273, 101302, 113812, 109431, 105582, 116969, 112635, 122391, 121872]
org_df = pd.DataFrame({'Experience': experience, 'Salary': salary})
org_df
# Out:
#     Experience  Salary
# 0          1.1   39343
# 1          1.3   46205
# 2          1.5   37731
# 3          2.0   43525
# 4          2.2   39891
# 5          2.9   56642
# 6          3.0   60150
# 7          3.2   54445
# 8          3.2   64445
# 9          3.7   57189
# 10         3.9   63218
# 11         4.0   55794
# 12         4.0   56957
# 13         4.1   57081
# 14         4.5   61111
# 15         4.9   67938
# 16         5.1   66029
# 17         5.3   83088
# 18         5.9   81363
# 19         6.0   93940
# 20         6.8   91738
# 21         7.1   98273
# 22         7.9  101302
# 23         8.2  113812
# 24         8.7  109431
# 25         9.0  105582
# 26         9.5  116969
# 27         9.6  112635
# 28        10.3  122391
# 29        10.5  121872

# %% [markdown]
# ###
# ## Plotting DataFrame:
# ###

# %%
import matplotlib.pyplot as plt

plt.plot(org_df.Experience, org_df.Salary, marker = 'o', color = 'red')
plt.title('\nExperience vs Salary\n')
plt.xlabel('Years of Experience')
plt.ylabel('Salary in US$')
plt.grid()

# %% [markdown]
# ###
# ## Seperating independent values (x) and dependent values (y):
# ###

# %%
x = org_df[['Experience']]
y = org_df['Salary']

# %% [markdown]
# ###
# ## train_test_split:
# ###

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
y_test
# Out:
# 2      37731
# 28    122391
# 13     57081
# 10     63218
# 26    116969
# 24    109431
# Name: Salary, dtype: int64

# %% [markdown]
# ###
# ## Importing LinearRegression:
# ###

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ###
# ## Predicting values of unseen data (x_test):
# ###

# %%
model.predict(x_test)
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %% [markdown]
# ###
# ## DataFrame of Actual unseen values (y_test) and Predicted unseen values (model.predict(x_test)):
# ###

# %%
pd.DataFrame({'Actual Salaries(y_test)': y_test, 'Predicted Salaries(model.predict(x_test))': model.predict(x_test)})
# Out:
#     Actual Salaries(y_test)  Predicted Salaries(model.predict(x_test))
# 2                     37731                               40748.961841
# 28                   122391                              122699.622956
# 13                    57081                               64961.657170
# 10                    63218                               63099.142145
# 26                   116969                              115249.562855
# 24                   109431                              107799.502753

# %% [markdown]
# ###
# ## Evaluating Model Performance:
# ###

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

print(f'r2_score = {r2_score(y_test, model.predict(x_test))}')
print(f'Mean Absolute Error (MAE): {mean_absolute_error(y_test, model.predict(x_test))}')
print(f'Mean Squared Error (MSE): {mean_squared_error(y_test, model.predict(x_test))}')
print(f'Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, model.predict(x_test)))}')
# Out:
# r2_score = 0.988169515729126
# Mean Absolute Error (MAE): 2446.1723690465055
# Mean Squared Error (MSE): 12823412.298126549
# Root Mean Squared Error (RMSE): 3580.979237321343

# %% [markdown]
# ###
# ## Predicting Program:
# ###

# %%
print('Welcome to Linear Regression based Salary Predicting Program:\n')
ask = float(input('Enter experience in years: '))
print(f'The predicted salary according to {ask} years of experience is: {model.predict([[ask]])}')
# Out:
# Welcome to Linear Regression based Salary Predicting Program:
#
# Enter experience in years: 10
# The predicted salary according to 10.0 years of experience is: [119905.85041792]
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ###
# ## Standardization:
# ###

# %% [markdown]
# ###
# ## Importing Standard Scale:
# ###

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ###
# ## Standardizing the orignal dataframe (org_df):
# ###

# %%
df2 = org_df.copy()
scalar = StandardScaler()
df2_scaled_ = scalar.fit_transform(df2)
df2_scaled_

df2_scaled = pd.DataFrame(df2_scaled_, columns = ['Experience (in years)','Salary (in US$)'])
df2_scaled
# Out:
#     Experience (in years)  Salary (in US$)
# 0               -1.510053        -1.360113
# 1               -1.438373        -1.105527
# 2               -1.366693        -1.419919
# 3               -1.187494        -1.204957
# 4               -1.115814        -1.339781
# 5               -0.864935        -0.718307
# 6               -0.829096        -0.588158
# 7               -0.757416        -0.799817
# 8               -0.757416        -0.428810
# 9               -0.578216        -0.698013
# 10              -0.506537        -0.474333
# 11              -0.470697        -0.749769
# 12              -0.470697        -0.706620
# 13              -0.434857        -0.702020
# 14              -0.291498        -0.552504
# 15              -0.148138        -0.299217
# 16              -0.076458        -0.370043
# 17              -0.004779         0.262859
# 18               0.210261         0.198860
# 19               0.246100         0.665476
# 20               0.532819         0.583780
# 21               0.640339         0.826233
# 22               0.927058         0.938611
# 23               1.034577         1.402741
# 24               1.213777         1.240203
# 25               1.321296         1.097402
# 26               1.500496         1.519868
# 27               1.536336         1.359074
# 28               1.787215         1.721028
# 29               1.858894         1.701773

# %% [markdown]
# ###
# ## Seperating independent values (x) and dependent values (y) from df2_scaled:
# ###

# %%
x1 = df2_scaled[['Experience (in years)']]
y1 = df2_scaled['Salary (in US$)']

# %% [markdown]
# ###
# ## train_test_split:
# ###

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split( x1, y1, test_size = 0.2, random_state = 0)
y1_test
# Out:
# 2    -1.419919
# 28    1.721028
# 13   -0.702020
# 10   -0.474333
# 26    1.519868
# 24    1.240203
# Name: Salary (in US$), dtype: float64

# %% [markdown]
# ###
# ## Importing LinearRegression:
# ###

# %%
from sklearn.linear_model import LinearRegression

model1 = LinearRegression()
model1.fit( x1_train, y1_train)
# Out:
# LinearRegression()

# %% [markdown]
# ###
# ## Predicting values of unseen data (x1_test):
# ###

# %%
model1.predict(x1_test)
# Out:
# array([-1.30795042,  1.73247863, -0.40964184, -0.4787425 ,  1.45607599,
#         1.17967335])

# %% [markdown]
# ###
# ## Actual unseen values (y1_test) and Predicted unseen values (model1.predict(x1_test)):
# ###

# %%
pd.DataFrame({'Actual Value': y1_test, 'Predicted': model1.predict(x1_test)})
# Out:
#     Actual Value  Predicted
# 2      -1.419919  -1.307950
# 28      1.721028   1.732479
# 13     -0.702020  -0.409642
# 10     -0.474333  -0.478742
# 26      1.519868   1.456076
# 24      1.240203   1.179673

# %% [markdown]
# ###
# ## Evaluating Model Performance:
# ###

# %%
print(f'r2_score = {r2_score(y1_test, model1.predict(x1_test))}')
print(f'Mean Absolute Error (MAE): {mean_absolute_error(y1_test, model1.predict(x1_test))}')
print(f'Mean Squared Error (MSE): {mean_squared_error(y1_test, model1.predict(x1_test))}')
print(f'Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y1_test, model1.predict(x1_test)))}')
# Out:
# r2_score = 0.988169515729126
# Mean Absolute Error (MAE): 0.09075477148619619
# Mean Squared Error (MSE): 0.01765096397693727
# Root Mean Squared Error (RMSE): 0.1328569304813914

# %% [markdown]
# ###
# ## Predicting Program:
# ###

# %%
# Original value = (standardized value * std) + mean

print('Welcome to Linear Regression based Salary Predicting Program:\n\nEnter any standarized value:')

ask1_ = float(input('\nEnter experience in years: '))
pred_ = model1.predict([[ask1_]])

ask1 = float(ask1_)
pred = float(pred_)

exp = (ask1 * 2.790189) + 5.3133333333333335
sal = (pred * 26953.65024877583) + 76003.0

print(f'\nResult:\nThe predicted salary according to {ask1} ({exp:.3f}) years of experience is: {pred:.3f} ({sal:.3f})')
# Out:
# Welcome to Linear Regression based Salary Predicting Program:
#
# Enter any standarized value:
#
# Enter experience in years: -0.470697
#
# Result:
# The predicted salary according to -0.470697 (4.000) years of experience is: -0.444 (64030.397)
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ###
# ## Final Comparision of test dataset:
# ###

# %%
pd.DataFrame({'Actual Salaries': y_test, 'Predicted Salaries': model.predict(x_test), 'Actual Salaries(Standardized)': y1_test, 'Predicted Salaries(standardized)': model1.predict(x1_test)})
# Out:
#     Actual Salaries  Predicted Salaries  Actual Salaries(Standardized)  \
# 2             37731        40748.961841                      -1.419919
# 28           122391       122699.622956                       1.721028
# 13            57081        64961.657170                      -0.702020
# 10            63218        63099.142145                      -0.474333
# 26           116969       115249.562855                       1.519868
# 24           109431       107799.502753                       1.240203
#
#     Predicted Salaries(standardized)
# 2                          -1.307950
# 28                          1.732479
# 13                         -0.409642
# 10                         -0.478742
# 26                          1.456076
# 24                          1.179673

# %% [markdown]
# ###
# ## Final Comparision of train dataset:
# ###

# %%
pd.DataFrame({'Actual Salaries': y_train, 'Predicted Salaries': model.predict(x_train), 'Actual Salaries(Standarized)': y1_train, 'Predicted Salaries(standarized)': model1.predict(x1_train)})
# Out:
#     Actual Salaries  Predicted Salaries  Actual Salaries(Standarized)  \
# 27           112635       116180.820367                      1.359074
# 11            55794        64030.399658                     -0.749769
# 17            83088        76136.747322                      0.262859
# 22           101302       100349.442652                      0.938611
# 5             56642        53786.567018                     -0.718307
# 16            66029        74274.232297                     -0.370043
# 8             64445        56580.339556                     -0.428810
# 14            61111        68686.687221                     -0.552504
# 23           113812       103143.215190                      1.402741
# 20            91738        90105.610012                      0.583780
# 1             46205        38886.446815                     -1.105527
# 29           121872       124562.137981                      1.701773
# 6             60150        54717.824531                     -0.588158
# 4             39891        47267.764429                     -1.339781
# 18            81363        81724.292398                      0.198860
# 19            93940        82655.549911                      0.665476
# 9             57189        61236.627120                     -0.698013
# 7             54445        56580.339556                     -0.799817
# 25           105582       110593.275291                      1.097402
# 3             43525        45405.249404                     -1.204957
# 0             39343        37023.931790                     -1.360113
# 21            98273        92899.382550                      0.826233
# 15            67938        72411.717272                     -0.299217
# 12            56957        64030.399658                     -0.706620
#
#     Predicted Salaries(standarized)
# 27                         1.490626
# 11                        -0.444192
# 17                         0.004962
# 22                         0.903271
# 5                         -0.824246
# 16                        -0.064139
# 8                         -0.720595
# 14                        -0.271441
# 23                         1.006922
# 20                         0.523217
# 1                         -1.377051
# 29                         1.801579
# 6                         -0.789695
# 4                         -1.066098
# 18                         0.212264
# 19                         0.246814
# 9                         -0.547843
# 7                         -0.720595
# 25                         1.283324
# 3                         -1.135199
# 0                         -1.446152
# 21                         0.626868
# 15                        -0.133239
# 12                        -0.444192

# %% [markdown]
# ###
# ## Final Comparision of whole dataset:
# ###

# %%
pd.DataFrame({'Actual Salaries': y, 'Predicted Salaries': model.predict(x), 'Actual Salaries(Standarized)': y1, 'Predicted Salaries(standarized)': model1.predict(x1)})
# Out:
#     Actual Salaries  Predicted Salaries  Actual Salaries(Standarized)  \
# 0             39343        37023.931790                     -1.360113
# 1             46205        38886.446815                     -1.105527
# 2             37731        40748.961841                     -1.419919
# 3             43525        45405.249404                     -1.204957
# 4             39891        47267.764429                     -1.339781
# 5             56642        53786.567018                     -0.718307
# 6             60150        54717.824531                     -0.588158
# 7             54445        56580.339556                     -0.799817
# 8             64445        56580.339556                     -0.428810
# 9             57189        61236.627120                     -0.698013
# 10            63218        63099.142145                     -0.474333
# 11            55794        64030.399658                     -0.749769
# 12            56957        64030.399658                     -0.706620
# 13            57081        64961.657170                     -0.702020
# 14            61111        68686.687221                     -0.552504
# 15            67938        72411.717272                     -0.299217
# 16            66029        74274.232297                     -0.370043
# 17            83088        76136.747322                      0.262859
# 18            81363        81724.292398                      0.198860
# 19            93940        82655.549911                      0.665476
# 20            91738        90105.610012                      0.583780
# 21            98273        92899.382550                      0.826233
# 22           101302       100349.442652                      0.938611
# 23           113812       103143.215190                      1.402741
# 24           109431       107799.502753                      1.240203
# 25           105582       110593.275291                      1.097402
# 26           116969       115249.562855                      1.519868
# 27           112635       116180.820367                      1.359074
# 28           122391       122699.622956                      1.721028
# 29           121872       124562.137981                      1.701773
#
#     Predicted Salaries(standarized)
# 0                         -1.446152
# 1                         -1.377051
# 2                         -1.307950
# 3                         -1.135199
# 4                         -1.066098
# 5                         -0.824246
# 6                         -0.789695
# 7                         -0.720595
# 8                         -0.720595
# 9                         -0.547843
# 10                        -0.478742
# 11                        -0.444192
# 12                        -0.444192
# 13                        -0.409642
# 14                        -0.271441
# 15                        -0.133239
# 16                        -0.064139
# 17                         0.004962
# 18                         0.212264
# 19                         0.246814
# 20                         0.523217
# 21                         0.626868
# 22                         0.903271
# 23                         1.006922
# 24                         1.179673
# 25                         1.283324
# 26                         1.456076
# 27                         1.490626
# 28                         1.732479
# 29                         1.801579
